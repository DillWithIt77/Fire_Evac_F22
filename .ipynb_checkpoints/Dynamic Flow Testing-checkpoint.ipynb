# %% [markdown]
# #### Import Libraries

# %%
import numpy as np
import networkx as nx
import math
import time
from scipy.interpolate import UnivariateSpline
import osmnx as ox
import matplotlib.pyplot as plt
from pyproj import CRS, Transformer
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely.ops import transform

# %% [markdown]
# #### Define Functions Used in Code

# %%
def time_expand(graph, time_int_size, num_time_int):
    start = time.time()
    orig_nodes = list(graph.nodes)
    orig_edges = list(graph.edges)
    ten = nx.MultiDiGraph()

    ###add in all nodes for time-expanded network
    node_num = 1
    for j in range(num_time_int):
        for i in range(len(orig_nodes)):
            if j == 0:
                node_name = f'{i+1}-{j}'
                ten.add_node(node_num, name = node_name, level = j, sup_dem = graph._node[i]['sup_dem'])
                node_num += 1
            else:
                node_name = f'{i+1}-{j}'
                ten.add_node(node_num, name = node_name, level = j, sup_dem = 0)
                node_num += 1
                
            
    ###add in hold over arcs for supply/demand nodes
    node_num = 0
    for i in range(len(orig_nodes)):
        if graph._node[i]['sup_dem'] >  0:
            for j in range(num_time_int-1):
                ten.add_edge((i+1)+(len(orig_nodes)*j),(i+1)+(len(orig_nodes)*(j+1)),cost = 0, upper =  graph._node[i]['sup_dem'] , lower = 0)
        elif graph._node[i]['sup_dem'] <  0:
            for j in range(num_time_int-1):
                ten.add_edge((i+1)+(len(orig_nodes)*j),(i+1)+(len(orig_nodes)*(j+1)),cost = 0, upper =  -graph._node[i]['sup_dem'] , lower = 0 )
    
    ###in the case of a multidigraph
    if graph.is_multigraph():
        node_num = 0
        for j in range(num_time_int-1):
            for i in range(len(orig_nodes)):
                ###keep track of node number for the overall network (need to account for nodes in the expansions)
                node_num +=1
                for k in range(len(orig_nodes)):
                    for m in range(graph.number_of_edges(i,k)+1):
                        ###check if edge exists in graph
                        if (i,k,m) in orig_edges:
                            ###deteremine how many time intervals it will cross
                            time_int_end = math.ceil(graph[i][k][m]['travel_time']/time_int_size)
                            ###check if the number it crosses exist in the network
                            if time_int_end+j< num_time_int:
                                ####add edge to time-expanded network
                                ten.add_edge(node_num,(node_num)+(k-i)+(len(orig_nodes)*time_int_end),cost = graph[i][k][m]['cost'] ,upper = graph[i][k][m]['upper'], lower = 0)
                            
    ###in the case of a digraph that is not a multdigraph
    elif graph.is_directed():
        node_num = 0
        for j in range(num_time_int-1):
            for i in range(len(orig_nodes)):
                ###keep track of node number for the overall network (need to account for nodes in the expansions)
                node_num +=1
                for k in range(len(orig_nodes)):
                    ###check if edge exists in graph
                    if (i,k) in orig_edges:
                        ###deteremine how many time intervals it will cross
                        time_int_end = math.ceil(graph[i][k]['travel_time']/time_int_size)
                        ###check if the number it crosses exist in the network
                        if time_int_end+j< num_time_int:
                            ####add edge to time-expanded network
                            ten.add_edge(node_num,(node_num)+(k-i)+(len(orig_nodes)*time_int_end),cost = graph[i][k]['cost'] ,upper = graph[i][k]['upper'], lower = 0)
    else:
        raise Exception("Must Input a DiGraph or MultiDiGraph")
        
    
    end = time.time()
    ###used for checking how long larger networks/expansions take to construct
    if end-start > 1:
        print('Number of Time Intervals:', num_time_int)
        print('Build Time: ',end-start, ' seconds')
    return ten

# %%
MOORE_AFTER_BREAK_SPLINE = UnivariateSpline(
    [20, 30, 40, 50, 60, 70, 80, 90, 100],
    [3.9, 6, 11, 18, 27, 39, 54, 58, 84],
)
MOORE_BEFORE_BREAK_SPLINE = UnivariateSpline(
    [20, 30, 40, 50, 60, 70, 80, 90, 100],
    [6, 8, 11, 14, 17, 19, 22, 25, 28],
)

MOORE_SAFE_BREAKING_DISTANCE = lambda x: MOORE_AFTER_BREAK_SPLINE(
    x
) + MOORE_BEFORE_BREAK_SPLINE(x)

def moore(lanes: float, max_speed: float):
    return 1000 * max_speed / MOORE_SAFE_BREAKING_DISTANCE(max_speed) * lanes

def add_capacities(G, method=moore):

    G = G.copy()
    cap = []
    
    for u, v, i in G.edges:
        edge_data = G.get_edge_data(u, v, i)
        raw_lanes = edge_data.get("lanes")
        
        if raw_lanes is None:
            lanes = 1
            
        elif isinstance(raw_lanes, str):
            lanes = int(raw_lanes) / 2  
            
        elif isinstance(raw_lanes, list):
            lanes = sum(int(x) for x in raw_lanes) / 2
            
        G[u][v][i]["upper"] = int(method(lanes, edge_data["speed_kph"]))
    return G

# %%
###don't need for max flow/quickest flow
def add_costs(G, costs:[int, np.ndarray] = 0):
    if type(costs) == int:
        for u,v,i in G.edges:
            G[u][v][i]['cost'] = costs
    else:
        count = 0
        for u,v,i in G.edges:
            G[u][v][i]['cost'] = costs[count]
    return G

# %%
def add_orig_dest(G, sup_dem:[int, np.ndarray]):
    if type(sup_dem) == int:
        for i in G.nodes:
            G._node[i]['sup_dem'] = sup_dem
    else:
        for i in G.nodes:
            G._node[i]['sup_dem'] = sup_dem[i]
    return G

# %%
def add_s_t(orig_graph, ten_graph, num_time_int, M):
    orig_nodes = list(orig_graph.nodes)
    ten_nodes = list(ten_graph.nodes)
    
    s = 0
    t = len(ten_nodes)+1
    
    ten_graph.add_node(s,name = f'{s}-{0}',level = 0)
    ten_graph.add_node(t,name = f'{len(orig_nodes)}-{num_time_int-1}',level = num_time_int-1)
    
    for i in range(len(orig_nodes)):
        if orig_graph._node[i]['sup_dem'] > 0:
            ten_graph.add_edge(s, i+1, cost = 0, upper = M, lower = 0)
        elif orig_graph._node[i]['sup_dem'] < 0:
            ten_graph.add_edge((i+1) + ((num_time_int-1) * len(orig_nodes)),t, cost = 0, upper = M, lower = 0)
        # if orig_graph._node[i]['sup_dem'] > 0:
        #     j = i+1
        #     while j <= t-1:
        #         ten_graph.add_edge(s, j, cost = 0, upper = M, lower = 0)
        #         j += len(orig_nodes)
        # elif orig_graph._node[i]['sup_dem'] < 0:
        #     j = i+1
        #     while j <= t-1:
        #         ten_graph.add_edge(j,t, cost = 0, upper = M, lower = 0)
        #         j += len(orig_nodes)
                
    return ten_graph

# %%
###note that this function does not account for the cost of each edge, just the capacity
def simplify_multigraph(graph):
    num_nodes = len(graph.nodes)
    edges = graph.edges
    
    simp_graph = nx.DiGraph()
    simp_graph.add_nodes_from(graph.nodes(data=True))
    
    for i in range(num_nodes+1):
        for j in range(num_nodes+1):
            if (i,j) in edges:
                num_edges = graph.number_of_edges(i,j)
                tot_cap = graph[i][j][num_edges-1]['upper']
                if num_edges > 1:
                    for k in range(1,num_edges):
                        tot_cap = tot_cap + graph[i][j][k]['upper']
                simp_graph.add_edge(i,j, upper = tot_cap, lower = 0)
            
    return simp_graph

# %%
def color_max_flow(graph, flow_dict):
    num_nodes = len(graph.nodes)
    edges = graph.edges
    
    for i in range(num_nodes):
        for j in range(num_nodes):
            if (i,j) in edges:
                graph[i][j]['color'] = (0,0,0)
                if flow_dict[i][j] != 0:
                    graph[i][j]['color'] = (1,0,0)
                    
    return graph

# %%
def det_num_int(G,pop):
    # pop = 20
    flow_value = 0

    time_int_len = 1
    num_time_ints = 2 ###time zero is when num_time_ints = 1

    while flow_value < pop:
        ten = nx.MultiDiGraph()
        simp_tem = nx.DiGraph()
        max_flow_ten = nx.DiGraph()
        num_time_ints +=1
        
        ten = time_expand(G,time_int_len,num_time_ints)
        simp_ten = simplify_multigraph(ten)
        max_flow_ten = add_s_t(G, simp_ten, num_time_ints,1000)
        flow_value, flow_dict = nx.maximum_flow(max_flow_ten, 0, len(list(max_flow_ten.nodes))-1,capacity = 'upper')
        
    
    colored_max_flow_ten = color_max_flow(max_flow_ten,flow_dict)
    num_nodes = len(list(colored_max_flow_ten))
    pos = nx.multipartite_layout(ten, subset_key="level")
    pos[0]= np.array([pos[1][0],pos[1][1]+(pos[1][1]-pos[2][1])])
    pos[num_nodes-1] = np.array([pos[num_nodes-2][0],pos[num_nodes-2][1]-(pos[num_nodes-3][1]-pos[num_nodes-2][1])])
    colors = [colored_max_flow_ten[u][v]['color'] for u,v in colored_max_flow_ten.edges]
    nx.draw(colored_max_flow_ten, pos, edge_color=colors,with_labels = True)
    
    return (num_time_ints, flow_value, colored_max_flow_ten)

# %% [markdown]
# ### Toy Network Example

# %%
toy_net = nx.DiGraph()
toy_net.add_nodes_from(range(4))
toy_net.add_edges_from([(0,1),(0,2),(1,2),(1,3),(2,3)], cost = 0)
toy_net[0][1]['travel_time'] = 4
toy_net[0][2]['travel_time'] = 2
toy_net[1][2]['travel_time'] = 3
toy_net[1][3]['travel_time'] = 1
toy_net[2][3]['travel_time'] = 1
toy_net[0][1]['upper'] = 3
toy_net[0][2]['upper'] = 4
toy_net[1][2]['upper'] = 3
toy_net[1][3]['upper'] = 2
toy_net[2][3]['upper'] = 4
toy_net.nodes[0]['sup_dem'] = 9
toy_net.nodes[1]['sup_dem'] = 0
toy_net.nodes[2]['sup_dem'] = 0
toy_net.nodes[3]['sup_dem'] = -9

# %%
nx.draw(toy_net)

# %% [markdown]
# #### Draw Time Expanded Network (TEN)

# %%
test_copies = 6
test_time_int = 1

# %%
test_ten = time_expand(toy_net,test_time_int,test_copies)

# %%
pos = nx.multipartite_layout(test_ten, subset_key="level")
nx.draw(test_ten, pos, with_labels=True)

# %% [markdown]
# #### Add Single Source and Sink

# %%
test_ten = time_expand(toy_net,test_time_int,test_copies)
test_ten_copy = test_ten.copy()
max_flow_ten = add_s_t(toy_net,test_ten_copy, test_copies,15)
pos = nx.multipartite_layout(test_ten, subset_key="level")
pos[0]= np.array([pos[1][0],pos[1][1]+(pos[1][1]-pos[2][1])])
pos[len(list(max_flow_ten.nodes))-1] = np.array([pos[len(list(max_flow_ten.nodes))-2][0],pos[len(list(max_flow_ten.nodes))-2][1]-(pos[len(list(max_flow_ten.nodes))-3][1]-pos[len(list(max_flow_ten.nodes))-2][1])])

nx.draw(max_flow_ten, pos, with_labels = True)

# %% [markdown]
# #### Max Flow Algorithm Testing

# %%
supply = 3
num_time_ints, max_flow, toy_net_test = det_num_int(toy_net,supply)
print('Number of Time Intervals:',num_time_ints)
print('Flow Value:', max_flow)

# %% [markdown]
# ### Real-world Network Example

# %%
start = time.time()
#import data from osmnx, can input any city, state, etc.
G = ox.project_graph(ox.graph_from_place('Lyons Colorado', network_type='drive'))
print('Importing Network Complete')

#get rid of intersections that are not actually intersections
G = ox.simplification.consolidate_intersections(G, tolerance=10, rebuild_graph=True, dead_ends=True, reconnect_edges = True)
print('Simplication Complete')

#add edge speeds
G = ox.speed.add_edge_speeds(G)
print('Speed Added')

#add travel times
G = ox.speed.add_edge_travel_times(G)
print('Travel Time Added')

#add capacities (computed using moore method)
G = add_capacities(G)
print('Capacities Added')

###only need if doing something with min-cost
costs = 0
G = add_costs(G,costs)
print('Costs Added')

#sup_dem:int = 0
sup_dem = np.zeros(len(G.nodes))
sup_dem[0] = 20
sup_dem[len(G.nodes)-1] = -20
G = add_orig_dest(G,sup_dem)
print('Supply and Demand Values Added')

end = time.time()

print('Time to Build Original Network: ',end-start, ' seconds')

# %%
fig,ax = ox.plot_graph(G,show = False, close = False,node_size = 20)
plt.show()

# %% [markdown]
# #### Draw TEN

# %%
test_rw_copies = 3
test_rw_time_int = 5

test_rw_net = time_expand(G,test_rw_time_int,test_rw_copies)

# %%
pos = nx.multipartite_layout(test_rw_net, subset_key="level")
nx.draw(test_rw_net, pos, with_labels=True)

# %% [markdown]
# #### Add Singel Source and Sink

# %%
test_ten_rw = time_expand(G,test_rw_time_int,test_rw_copies)
test_ten_rw_copy = test_ten_rw.copy()
max_flow_ten_rw = add_s_t(G,test_ten_rw_copy, test_rw_copies,1000)
pos = nx.multipartite_layout(test_ten_rw, subset_key="level")
pos[0]= np.array([pos[1][0],pos[1][1]+(pos[1][1]-pos[2][1])])
pos[len(list(max_flow_ten_rw.nodes))-1] = np.array([pos[len(list(max_flow_ten_rw.nodes))-2][0],pos[len(list(max_flow_ten_rw.nodes))-2][1]-(pos[len(list(max_flow_ten_rw.nodes))-3][1]-pos[len(list(max_flow_ten_rw.nodes))-2][1])])

nx.draw(max_flow_ten_rw, pos, with_labels = True)

# %% [markdown]
# #### Max Flow Algorithm

# %%
num_time_ints, max_flow, G_test = det_num_int(G,4)
print('Number of Time Intervals:',num_time_ints)
print('Flow Value:', max_flow)

# %% [markdown]
# ### Fire Polygon Testing

# %%
def remove_graph_polygon(G, fire_polygon, smoke_polygon):
    ###find nodes inside poly to remove
    start_gs = time.process_time()
    gs_nodes = ox.utils_graph.graph_to_gdfs(G,nodes = True,edges = False, node_geometry = True)[['geometry']]
    gs_edges = ox.utils_graph.graph_to_gdfs(G,nodes = False, edges = True)[['geometry']]
    end_gs = time.process_time()
    print ("Time elapsed for gs: ", end_gs - start_gs)
#     to_remove = ox.utils_geo._intersect_index_quadrats(gs_nodes, polygon, quadrat_width, min_num)
    
    nodes_to_remove = []
    edges_to_remove = []
    start_to_remove = time.process_time()
    for point in gs_nodes['geometry']:
        ###currently this takes a long time to run, but a smaller polygon might make this run faster
        if point.intersects(smoke_polygon):
            node = ox.distance.nearest_nodes(G,point.x,point.y,return_dist=False)
            nodes_to_remove.append(node)
    for i in range(len(gs_edges)):
        entry =  gs_edges.iloc[i]
        if entry['geometry'].intersects(fire_polygon):
            entry = gs_edges.iloc[[i]]
            edges_to_remove.append(entry['geometry'].index[0])
    end_to_remove = time.process_time()
    print ("Time elapsed for remove list: ", end_to_remove - start_to_remove)
     
    start_rem_net = time.process_time()      
    G = G.copy()
    G.remove_nodes_from(nodes_to_remove)
    G.remove_edges_from(edges_to_remove)
    end_rem_net = time.process_time()
    print ("Time elapsed for remove from net: ", end_rem_net - start_rem_net)

    return (nodes_to_remove,edges_to_remove, G)

# %%
###lat/long
fire_origin = [40.229520, -105.263912]
radius = 0.4

###create fire_poly and smoke_poly in coordinate system of network
fire_poly = geodesic_point_buffer(G,fire_origin[0],fire_origin[1],radius)
smoke_poly = geodesic_point_buffer(G,fire_origin[0],fire_origin[1],radius*1.1)

# %%
###graph fire on network
fig,ax = ox.plot_graph(G,show = False, close = False,node_size = 20)
x,y = smoke_poly.exterior.xy
ax.fill(x,y,'#f1c232ff', alpha = 0.5)
x,y = fire_poly.exterior.xy
ax.fill(x,y,'#D22B2B', alpha = 0.7)
plt.show()

# %%
removed_nodes,removed_edges,net = remove_graph_polygon(G,fire_poly,smoke_poly)

# %%
fig,ax = ox.plot_graph(net,show = False, close = False,node_size = 20)
x,y = smoke_poly.exterior.xy
ax.fill(x,y,'#f1c232ff', alpha = 0.5)
x,y = fire_poly.exterior.xy
ax.fill(x,y,'#D22B2B', alpha = 0.7)
plt.show()

# %%
fire_origin = [40.229520, -105.263912]
lyons = G.copy()
fire_radius = 0.4
T = 4
removed_nodes,removed_edges = create_fire_mat(lyons, fire_origin,fire_radius,T)

# %%
def remove_arcs_TEN(TEN, orig_graph, fire_origin, radius, time_int, time_horizon):
    ###assume we are working with the simplified TEN (aka it has been trasformed into a digraph)
    
    fire_polygon = geodesic_point_buffer(orig_graph,fire_origin[0],fire_origin[1],radius)
    ####maybe adjust radius size with input, for now will leave set as 1.1
    smoke_polygon = geodesic_point_buffer(orig_graph,fire_origin[0],fire_origin[1],radius*1.1)

    removed_nodes,removed_edges,net = remove_graph_polygon(orig_graph,fire_polygon,smoke_polygon)

    for i in removed_nodes:
        for j in range(time_int,time_horizon+1):
                node = [x for x,y in TEN.nodes(data=True) if y['name']==f'{i+1}-{j}']
                TEN.remove_nodes_from(node)
    
    for i in removed_edges:
        if (i[0] not in removed_nodes) and (i[1] not in removed_nodes):
            ###account for digraph/multidigraph difference in orignal graph
            if orig_graph.is_multidigraph():
                travel_time = math.ceil(orig_graph[i[0]][i[1]][i[2]]['travel_time']/time_int_size)
                edge_cap = orig_graph[i[0]][i[1]][i[2]]['upper']
            elif orig_graph.is_direct():
                travel_time = math.ceil(orig_graph[i[0]][i[1]]['travel_time']/time_int_size)
                edge_cap = orig_graph[i[0]][i[1]]['upper']
            for j in range(time_int,time_horizon+1,travel_time):
                if j +travel_time < time_horizon:
                    node_1 = [x for x,y in TEN.nodes(data=True) if y['name']==f'{i[0]+1}-{j}']
                    node_2 = [x for x,y in TEN.nodes(data=True) if y['name']==f'{i[1]+1}-{j+travel_time}']
                    old_cap = TEN[node_1[0]][node_2[0]]['upper']
                    TEN[node_1[0]][node_2[0]]['upper'] = old-cap -edge_cap

# %%
def remove_arcs_toyTEN(TEN, orig_graph, removed_edges, removed_nodes, time_int, time_horizon,time_int_size):
    ###assume we are working with the simplified TEN (aka it has been trasformed into a digraph)
    for i in removed_nodes:
        for j in range(time_int,time_horizon+1):
            node = [x for x,y in TEN.nodes(data=True) if y['name']==f'{i+1}-{j}']
            TEN.remove_nodes_from(node)
    
    for i in removed_edges:
        if (i[0] not in removed_nodes) and (i[1] not in removed_nodes):
            ###account for digraph/multidigraph difference
            travel_time = math.ceil(orig_graph[i[0]][i[1]]['travel_time']/time_int_size)
            edge_cap = orig_graph[i[0]][i[1]]['upper']
            for j in range(time_int,time_horizon,travel_time):
                if j+travel_time < time_horizon:
                    node_1 = [x for x,y in TEN.nodes(data=True) if y['name']==f'{i[0]+1}-{j}']
                    node_2 = [x for x,y in TEN.nodes(data=True) if y['name']==f'{i[1]+1}-{j+travel_time}']
                    old_cap = TEN[node_1[0]][node_2[0]]['upper']
                    TEN[node_1[0]][node_2[0]]['upper'] = old_cap - edge_cap 

    return TEN

# %% [markdown]
# ### Node/Arc Removal while Constructing TEN testing

# %%
def time_expand_with_removal_toy(G, time_int_size, time_horizon,removed_nodes_mat, removed_edges_mat):
    start = time.time()
    orig_nodes = list(G.nodes)
    orig_edges = list(G.edges)
    ten = nx.MultiDiGraph()

    # removed_nodes_mat,removed_edges_mat = create_fire_mat(G, fire_origin, init_radius, time_horizon)

    ###add in all nodes for time-expanded network
    node_num = 1
    for j in range(time_horizon):
        for i in range(len(orig_nodes)):
            # print(i)
            #check not one of nodes that have been removed during that time interval
            # print(i not in removed_nodes_mat[j])
            if i not in removed_nodes_mat[j]:
                if j == 0:
                    node_name = f'{i+1}-{j}'
                    ten.add_node(node_num, name = node_name, level = j, sup_dem = G._node[i]['sup_dem'])
                    # node_num += 1
                else:
                    node_name = f'{i+1}-{j}'
                    ten.add_node(node_num, name = node_name, level = j, sup_dem = 0)
            node_num += 1
                
            
    ###add in hold over arcs for supply/demand nodes
    for i in range(len(orig_nodes)):
        if G._node[i]['sup_dem'] >  0:
            for j in range(time_horizon-1):
                if i not in removed_nodes_mat[j+1]:
                    ten.add_edge((i+1)+(len(orig_nodes)*j),(i+1)+(len(orig_nodes)*(j+1)),cost = 0, upper =  G._node[i]['sup_dem'] , lower = 0)
        elif G._node[i]['sup_dem'] <  0:
            for j in range(time_horizon-1):
                if i not in removed_nodes_mat[j+1]:
                    ten.add_edge((i+1)+(len(orig_nodes)*j),(i+1)+(len(orig_nodes)*(j+1)),cost = 0, upper =  -G._node[i]['sup_dem'] , lower = 0 )
    
    ###in the case of a multidigraph
    if G.is_multigraph():
        node_num = 0
        for j in range(time_horizon-1):
            for i in range(len(orig_nodes)):
                ###keep track of node number for the overall network (need to account for nodes in the expansions)
                node_num +=1
                if i not in removed_nodes_mat[j]:
                    for k in range(len(orig_nodes)):
                        for m in range(graph.number_of_edges(i,k)+1):
                            ###check if edge exists in graph
                            if (i,k,m) in orig_edges and (i,k,m) not in removed_edges_mat[j]:
                                ###deteremine how many time intervals it will cross
                                time_int_end = math.ceil(G[i][k][m]['travel_time']/time_int_size)
                                ###check if the number it crosses exist in the network
                                if time_int_end+j< time_horizon:
                                    ###check that end node exists during that time interval
                                    if k not in removed_nodes_mat[time_int_end+j]:
                                        ####add edge to time-expanded network
                                        ten.add_edge(node_num,(node_num)+(k-i)+(len(orig_nodes)*time_int_end),cost = G[i][k][m]['cost'] ,upper = G[i][k][m]['upper'], lower = 0)
                            
    ##in the case of a digraph that is not a multdigraph
    elif G.is_directed():
        node_num = 0
        for j in range(time_horizon-1):
            for i in range(len(orig_nodes)):
                ###keep track of node number for the overall network (need to account for nodes in the expansions)
                node_num +=1
                if i not in removed_nodes_mat[j]:
                    for k in range(len(orig_nodes)):
                        ###check if edge exists in graph
                        if (i,k) in orig_edges and (i,k) not in removed_edges_mat[j]:
                            ###deteremine how many time intervals it will cross
                            time_int_end = math.ceil(G[i][k]['travel_time']/time_int_size)
                            ###check if the number it crosses exist in the network
                            if time_int_end+j< time_horizon:
                                ###check that end node exists during that time interval
                                if k not in removed_nodes_mat[time_int_end+j]:
                                    ####add edge to time-expanded network
                                     ten.add_edge(node_num,(node_num)+(k-i)+(len(orig_nodes)*time_int_end),cost = G[i][k]['cost'] ,upper = G[i][k]['upper'], lower = 0)
    else:
        raise Exception("Must Input a DiGraph or MultiDiGraph")
    
    end = time.time()
    ###used for checking how long larger networks/expansions take to construct
    if end-start > 1:
        print('Number of Time Intervals:', num_time_int)
        print('Build Time: ',end-start, ' seconds')
    return ten

# %%
toy_net = nx.DiGraph()
toy_net.add_nodes_from(range(4))
toy_net.add_edges_from([(0,1),(0,2),(1,2),(1,3),(2,3)], cost = 0)
toy_net[0][1]['travel_time'] = 4
toy_net[0][2]['travel_time'] = 2
toy_net[1][2]['travel_time'] = 3
toy_net[1][3]['travel_time'] = 1
toy_net[2][3]['travel_time'] = 1
toy_net[0][1]['upper'] = 3
toy_net[0][2]['upper'] = 4
toy_net[1][2]['upper'] = 3
toy_net[1][3]['upper'] = 2
toy_net[2][3]['upper'] = 4
toy_net.nodes[0]['sup_dem'] = 9
toy_net.nodes[1]['sup_dem'] = 2
toy_net.nodes[2]['sup_dem'] = -2
toy_net.nodes[3]['sup_dem'] = -9

test_copies = 5
test_time_int = 1

removed_nodes_mat_test = [[],[],[0],[0],[0,1,3]]
# removed_nodes_mat_test = [[],[],[],[],[]]
removed_edges_mat_test = [[],[],[(0,1),(0,2)],[(0,1),(0,2)],[(0,1),(0,2),(1,2),(1,3)]]
# removed_edges_mat_test = [[],[],[],[],[]]


removed_arcs_ten = time_expand_with_removal_toy(toy_net, test_time_int, test_copies,removed_nodes_mat_test, removed_edges_mat_test)

# %%
pos = nx.multipartite_layout(removed_arcs_ten, subset_key="level")
nx.draw(removed_arcs_ten, pos, with_labels = True)

# %%
test_s_t = removed_arcs_ten.copy()
add_s_t_toy = add_s_t(toy_net,test_s_t,test_copies,removed_nodes_mat_test)
# Out:
# 20
# 16

# %%
pos = nx.multipartite_layout(test_s_t, subset_key="level")
pos[0]= np.array([pos[1][0]-(pos[1][1]-pos[2][1]),pos[1][1]])
pos[max(list(test_s_t.nodes))] = np.array([pos[max(list(test_s_t.nodes))-1][0]+(pos[1][1]-pos[2][1]),pos[max(list(test_s_t.nodes))-1][1]])

nx.draw(add_s_t_toy, pos, with_labels = True)

# %%
print(max(list(test_s_t.nodes)))
# Out:
# 20

# %%
def geodesic_point_buffer(graph,lat, lon, radius):
    """
    Creates circles from given latitude, longitude, and radius
    :param lat: latitude from original data
    :param lon: longitude from original data
    :param radius: radius from original data
    """
    # Azimuthal equidistant projection
    aeqd_proj = CRS.from_proj4(f"+proj=aeqd +lat_0={lat} +lon_0={lon} +x_0=0 +y_0=0")
    tfmr = Transformer.from_proj(aeqd_proj, aeqd_proj.geodetic_crs)
    buf = Point(0, 0).buffer(radius * 1609.34)  # distance in miles (converts from meters to miles)
    circle = Polygon(transform(tfmr.transform, buf).exterior.coords[:])
    net_trans = Transformer.from_crs(aeqd_proj.geodetic_crs, graph.graph['crs'])
    proj_circ = Polygon(transform(net_trans.transform,circle).exterior.coords[:])
    
    return proj_circ

# %%
def det_rem_parts(G, fire_polygon, smoke_polygon):
    ###find nodes inside poly to remove
    start_gs = time.process_time()
    gs_nodes = ox.utils_graph.graph_to_gdfs(G,nodes = True,edges = False, node_geometry = True)[['geometry']]
    gs_edges = ox.utils_graph.graph_to_gdfs(G,nodes = False, edges = True)[['geometry']]
    end_gs = time.process_time()
    # print ("Time elapsed for gs: ", end_gs - start_gs)

    nodes_to_remove = []
    edges_to_remove = []
    start_to_remove = time.process_time()
    for point in gs_nodes['geometry']:
        ###currently this takes a long time to run, but a smaller polygon might make this run faster
        if point.intersects(smoke_polygon):
            node = ox.distance.nearest_nodes(G,point.x,point.y,return_dist=False)
            nodes_to_remove.append(node)
    for i in range(len(gs_edges)):
        entry =  gs_edges.iloc[i]
        if entry['geometry'].intersects(fire_polygon):
            entry = gs_edges.iloc[[i]]
            edges_to_remove.append(entry['geometry'].index[0])
    end_to_remove = time.process_time()
    # print ("Time elapsed for create remove list: ", end_to_remove - start_to_remove)

    return (nodes_to_remove, edges_to_remove)

# %%
def create_fire_mat(G, fire_origin, init_radius, time_horizon):
    removed_node_mat = []
    removed_edge_mat = []
    for i in range(time_horizon):
        ###create fire_poly and smoke_poly in coordinate system of network
        # radius = init_radius+(0.025*i) #increase the radius by 0.025 of a meter with each time step
        radius = init_radius #increase the radius by a quarter meter with each time step
        fire_polygon = geodesic_point_buffer(G,fire_origin[0],fire_origin[1],radius)
        smoke_polygon = geodesic_point_buffer(G,fire_origin[0],fire_origin[1],radius*1.01)
                                              
        removed_nodes,removed_edges = det_rem_parts(G, fire_polygon, smoke_polygon)

        removed_node_mat.append(removed_nodes)
        removed_edge_mat.append(removed_edges)
    return (removed_node_mat, removed_edge_mat)

# %%
def time_expand_with_removal(G, time_int_size, time_horizon,fire_origin, init_radius):
    start = time.time()
    orig_nodes = list(G.nodes)
    orig_edges = list(G.edges)
    ten = nx.MultiDiGraph()

    removed_nodes_mat,removed_edges_mat = create_fire_mat(G, fire_origin, init_radius, time_horizon)

    ###add in all nodes for time-expanded network
    node_num = 1
    for j in range(time_horizon):
        for i in range(len(orig_nodes)):
            #check not one of nodes that have been removed during that time interval
            if i not in removed_nodes_mat[j]:
                if j == 0:
                    node_name = f'{i+1}-{j}'
                    ten.add_node(node_num, name = node_name, level = j, sup_dem = G._node[i]['sup_dem'])
                    # node_num += 1
                else:
                    node_name = f'{i+1}-{j}'
                    ten.add_node(node_num, name = node_name, level = j, sup_dem = 0)
            node_num += 1
                
            
    ###add in hold over arcs for supply/demand nodes
    for i in range(len(orig_nodes)):
        if G._node[i]['sup_dem'] >  0:
            for j in range(time_horizon-1):
                if i not in removed_nodes_mat[j+1]:
                    ten.add_edge((i+1)+(len(orig_nodes)*j),(i+1)+(len(orig_nodes)*(j+1)),cost = 0, upper =  G._node[i]['sup_dem'] , lower = 0)
        elif G._node[i]['sup_dem'] <  0:
            for j in range(time_horizon-1):
                if i not in removed_nodes_mat[j+1]:
                    ten.add_edge((i+1)+(len(orig_nodes)*j),(i+1)+(len(orig_nodes)*(j+1)),cost = 0, upper =  -G._node[i]['sup_dem'] , lower = 0 )
    
    ###in the case of a multidigraph
    if G.is_multigraph():
        node_num = 0
        for j in range(time_horizon-1):
            for i in range(len(orig_nodes)):
                ###keep track of node number for the overall network (need to account for nodes in the expansions)
                node_num +=1
                if i not in removed_nodes_mat[j]:
                    for k in range(len(orig_nodes)):
                        for m in range(G.number_of_edges(i,k)+1):
                            ###check if edge exists in graph
                            if (i,k,m) in orig_edges and (i,k,m) not in removed_edges_mat[j]:
                                ###deteremine how many time intervals it will cross
                                time_int_end = math.ceil(G[i][k][m]['travel_time']/time_int_size)
                                ###check if the number it crosses exist in the network
                                if time_int_end+j< time_horizon:
                                    ###check that end node exists during that time interval
                                    if k not in removed_nodes_mat[time_int_end+j]:
                                        ####add edge to time-expanded network
                                        ten.add_edge(node_num,(node_num)+(k-i)+(len(orig_nodes)*time_int_end),cost = G[i][k][m]['cost'] ,upper = G[i][k][m]['upper'], lower = 0)
                            
    ##in the case of a digraph that is not a multdigraph
    elif G.is_directed():
        node_num = 0
        for j in range(time_horizon-1):
            for i in range(len(orig_nodes)):
                ###keep track of node number for the overall network (need to account for nodes in the expansions)
                node_num +=1
                if i not in removed_nodes_mat[j]:
                    for k in range(len(orig_nodes)):
                        ###check if edge exists in graph
                        if (i,k) in orig_edges and (i,k) not in removed_edges_mat[j]:
                            ###deteremine how many time intervals it will cross
                            time_int_end = math.ceil(G[i][k]['travel_time']/time_int_size)
                            ###check if the number it crosses exist in the network
                            if time_int_end+j< time_horizon:
                                ###check that end node exists during that time interval
                                if k not in removed_nodes_mat[time_int_end+j]:
                                    ####add edge to time-expanded network
                                     ten.add_edge(node_num,(node_num)+(k-i)+(len(orig_nodes)*time_int_end),cost = G[i][k]['cost'] ,upper = G[i][k]['upper'], lower = 0)
    else:
        raise Exception("Must Input a DiGraph or MultiDiGraph")


    ###Remove isolated nodes in TEN
    ten.remove_nodes_from(list(nx.isolates(ten)))
    
    end = time.time()
    ###used for checking how long larger networks/expansions take to construct
    if end-start > 1:
        print('Number of Time Intervals:', time_horizon)
        print('Build Time: ',end-start, ' seconds')
    return (ten, removed_nodes_mat, removed_edges_mat)

# %%
start = time.time()
#import data from osmnx, can input any city, state, etc.
G = ox.project_graph(ox.graph_from_place('Lyons Colorado', network_type='drive'))
print('Importing Network Complete')

#get rid of intersections that are not actually intersections
G = ox.simplification.consolidate_intersections(G, tolerance=10, rebuild_graph=True, dead_ends=True, reconnect_edges = True)
print('Simplication Complete')

#add edge speeds
G = ox.speed.add_edge_speeds(G)
print('Speed Added')

#add travel times
G = ox.speed.add_edge_travel_times(G)
print('Travel Time Added')

#add capacities (computed using moore method)
G = add_capacities(G)
print('Capacities Added')

###only need if doing something with min-cost
costs = 0
G = add_costs(G,costs)
print('Costs Added')

#sup_dem:int = 0
sup_dem = np.zeros(len(G.nodes))
sup_dem[0] = 20
sup_dem[len(G.nodes)-1] = -20
G = add_orig_dest(G,sup_dem)
print('Supply and Demand Values Added')

end = time.time()

print('Time to Build Original Network: ',end-start, ' seconds')
# Out:
# Importing Network Complete
# Simplication Complete
# Speed Added
# Travel Time Added
# Capacities Added
# Costs Added
# Supply and Demand Values Added
# Time to Build Original Network:  0.5789155960083008  seconds

# %%
test_rw_copies = 6
test_rw_time_int = 1

fire_origin = [40.229520, -105.263912]
lyons = G.copy()
fire_radius = 0.0004

test_rw_ten = time_expand_with_removal(lyons, test_rw_time_int, test_rw_copies, fire_origin, fire_radius)
# Out:
# Time elapsed for gs:  0.0
# Time elapsed for create remove list:  0.0
# Time elapsed for gs:  0.0
# Time elapsed for create remove list:  0.03125
# Time elapsed for gs:  0.015625
# Time elapsed for create remove list:  0.015625
# Time elapsed for gs:  0.0
# Time elapsed for create remove list:  0.015625
# Time elapsed for gs:  0.015625
# Time elapsed for create remove list:  0.015625
# Time elapsed for gs:  0.0
# Time elapsed for create remove list:  0.03125

# %%
pos = nx.multipartite_layout(test_rw_ten, subset_key="level")
nx.draw(test_rw_ten, pos, with_labels = True)

# %% [markdown]
# ### Updating max flow functions to work with TEN in which nodes and arcs are removed

# %%
def add_s_t(G, ten, time_horizon,removed_nodes_mat):
    orig_nodes = list(G.nodes)
    ten_nodes = list(ten.nodes)

    sup_nodes = [x for x,y in G.nodes(data=True) if y['sup_dem'] > 0]
    dem_nodes = [x for x,y in G.nodes(data=True) if y['sup_dem'] < 0]
    
    s = 0
    t = max(ten_nodes)+1
    
    ten.add_node(s,name = f'{s}-{0}',level = 0)
    ten.add_node(t,name = f'{len(orig_nodes)}-{time_horizon-1}',level = time_horizon-1)
    
    for i in range(len(orig_nodes)):
        if i in sup_nodes:
            ten.add_edge(s, i+1, cost = 0, upper = G._node[i]['sup_dem'], lower = 0)
        elif i in dem_nodes:
            ###need to add in check for last time interval node is still available
            for k in range(time_horizon-1):
                added = False
                if i in removed_nodes_mat[k+1]:
                    print((i+1) + ((k) * len(orig_nodes)))
                    ten.add_edge((i+1) + ((k) * len(orig_nodes)),t, cost = 0, upper = -G._node[i]['sup_dem'], lower = 0)
                    added = True
                    break;
            if added is False:
                ten.add_edge((i+1) + ((time_horizon-1) * len(orig_nodes)),t, cost = 0, upper = -G._node[i]['sup_dem'], lower = 0)
    return ten

# %%
removed_nodes_mat,removed_edges_mat = create_fire_mat(G, fire_origin, fire_radius, test_rw_copies)
test_s_t = add_s_t(lyons,test_rw_ten,test_rw_copies,removed_nodes_mat)
# Out:
# Time elapsed for gs:  0.015625
# Time elapsed for create remove list:  0.0
# Time elapsed for gs:  0.015625
# Time elapsed for create remove list:  0.0
# Time elapsed for gs:  0.0
# Time elapsed for create remove list:  0.015625
# Time elapsed for gs:  0.0
# Time elapsed for create remove list:  0.015625
# Time elapsed for gs:  0.015625
# Time elapsed for create remove list:  0.0
# Time elapsed for gs:  0.015625
# Time elapsed for create remove list:  0.015625

# %%
pos = nx.multipartite_layout(test_rw_ten, subset_key="level")
pos[0]= np.array([pos[1][0]-(pos[1][1]-pos[2][1]),pos[1][1]])
pos[max(list(test_rw_ten.nodes))] = np.array([pos[max(list(test_rw_ten.nodes))-1][0]+(pos[1][1]-pos[2][1]),pos[max(list(test_rw_ten.nodes))-1][1]])

nx.draw(test_s_t, pos, with_labels = True)


# pos = nx.multipartite_layout(test_rw_ten, subset_key="level")
# nx.draw(test_rw_ten, pos, with_labels = True)

# %%
###note that this function does not account for the cost of each edge, just the capacity
def simplify_multigraph(graph):
    num_nodes = len(graph.nodes)
    edges = graph.edges
    
    simp_graph = nx.DiGraph()
    simp_graph.add_nodes_from(graph.nodes(data=True))
    
    for i in range(num_nodes+1):
        for j in range(num_nodes+1):
            if (i,j) in edges:
                num_edges = graph.number_of_edges(i,j)
                tot_cap = graph[i][j][num_edges-1]['upper']
                if num_edges > 1:
                    for k in range(1,num_edges):
                        tot_cap = tot_cap + graph[i][j][k]['upper']
                simp_graph.add_edge(i,j, upper = tot_cap, lower = 0)
            
    return simp_graph

# %%
def color_max_flow(graph, flow_dict):
    num_nodes = len(graph.nodes)
    edges = graph.edges
    
    for i in range(num_nodes):
        for j in range(num_nodes):
            if (i,j) in edges:
                graph[i][j]['color'] = (0,0,0)
                if flow_dict[i][j] != 0:
                    graph[i][j]['color'] = (1,0,0)
                    
    return graph

# %%
def det_num_int(G, pop, fire_orgin, init_radius):
    flow_value = 0

    time_int_len = 1
    num_time_ints = 2 ###time zero is when num_time_ints = 1

    while flow_value < pop:
        ten = nx.MultiDiGraph()
        simp_tem = nx.DiGraph()
        max_flow_ten = nx.DiGraph()
        num_time_ints +=1
        
        ten, removed_nodes_mat, removed_edges_mat = time_expand_with_removal(G, time_int_len, num_time_ints, fire_origin, init_radius)
        simp_ten = simplify_multigraph(ten)
        max_flow_ten = add_s_t(G, simp_ten, num_time_ints, removed_nodes_mat)
        flow_value, flow_dict = nx.maximum_flow(max_flow_ten, 0, max(list(max_flow_ten.nodes)),capacity = 'upper')
        
    
    colored_max_flow_ten = color_max_flow(max_flow_ten,flow_dict)
    num_nodes = len(list(colored_max_flow_ten))
    pos = nx.multipartite_layout(ten, subset_key="level")
    pos[0]= np.array([pos[1][0],pos[1][1]+(pos[1][1]-pos[2][1])])
    pos[num_nodes-1] = np.array([pos[num_nodes-2][0],pos[num_nodes-2][1]-(pos[num_nodes-3][1]-pos[num_nodes-2][1])])
    colors = [colored_max_flow_ten[u][v]['color'] for u,v in colored_max_flow_ten.edges]
    nx.draw(colored_max_flow_ten, pos, edge_color=colors,with_labels = True)
    
    return (num_time_ints, flow_value, colored_max_flow_ten)

# %%
fire_origin = [40.229520, -105.263912]
lyons = G.copy()
fire_radius =  0

num_time_ints, max_flow, G_test = det_num_int(lyons,1, fire_origin, fire_radius)
print('Number of Time Intervals:',num_time_ints)
print('Flow Value:', max_flow)
# Out:
# Number of Time Intervals: 13
# Build Time:  1.0812041759490967  seconds
# Number of Time Intervals: 14
# Build Time:  1.1824228763580322  seconds
# Number of Time Intervals: 15
# Build Time:  1.2437241077423096  seconds
# Number of Time Intervals: 16
# Build Time:  1.3206870555877686  seconds
# Number of Time Intervals: 17
# Build Time:  1.4353818893432617  seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[136], line 5
#       2 lyons = G.copy()
#       3 fire_radius =  0
# ----> 5 num_time_ints, max_flow, G_test = det_num_int(lyons,1, fire_origin, fire_radius)
#       6 print('Number of Time Intervals:',num_time_ints)
#       7 print('Flow Value:', max_flow)
#
# Cell In[128], line 17, in det_num_int(G, pop, fire_orgin, init_radius)
#      11 num_time_ints +=1
#      13 # ten = time_expand(G,time_int_len,num_time_ints)
#      14 # simp_ten = simplify_multigraph(ten)
#      15 # max_flow_ten = add_s_t(G, simp_ten, num_time_ints,1000)
#      16 # flow_value, flow_dict = nx.maximum_flow(max_flow_ten, 0, len(list(max_flow_ten.nodes))-1,capacity = 'upper')
# ---> 17 ten, removed_nodes_mat, removed_edges_mat = time_expand_with_removal(G, time_int_len, num_time_ints, fire_origin, init_radius)
#      18 simp_ten = simplify_multigraph(ten)
#      19 max_flow_ten = add_s_t(G, simp_ten, num_time_ints,removed_nodes_mat)
#
# Cell In[121], line 7, in time_expand_with_removal(G, time_int_size, time_horizon, fire_origin, init_radius)
#       4 orig_edges = list(G.edges)
#       5 ten = nx.MultiDiGraph()
# ----> 7 removed_nodes_mat,removed_edges_mat = create_fire_mat(G, fire_origin, init_radius, time_horizon)
#       9 ###add in all nodes for time-expanded network
#      10 node_num = 1
#
# Cell In[133], line 11, in create_fire_mat(G, fire_origin, init_radius, time_horizon)
#       8 fire_polygon = geodesic_point_buffer(G,fire_origin[0],fire_origin[1],radius)
#       9 smoke_polygon = geodesic_point_buffer(G,fire_origin[0],fire_origin[1],radius*1.01)
# ---> 11 removed_nodes,removed_edges = det_rem_parts(G, fire_polygon, smoke_polygon)
#      13 removed_node_mat.append(removed_nodes)
#      14 removed_edge_mat.append(removed_edges)
#
# Cell In[130], line 5, in det_rem_parts(G, fire_polygon, smoke_polygon)
#       3 start_gs = time.process_time()
#       4 gs_nodes = ox.utils_graph.graph_to_gdfs(G,nodes = True,edges = False, node_geometry = True)[['geometry']]
# ----> 5 gs_edges = ox.utils_graph.graph_to_gdfs(G,nodes = False, edges = True)[['geometry']]
#       6 end_gs = time.process_time()
#       7 # print ("Time elapsed for gs: ", end_gs - start_gs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\osmnx\utils_graph.py:81, in graph_to_gdfs(G, nodes, edges, node_geometry, fill_edge_geometry)
#      78         return LineString((Point((x[u], y[u])), Point((x[v], y[v]))))
#      80     geom = map(_make_geom, u, v, data)
# ---> 81     gdf_edges = gpd.GeoDataFrame(data, crs=crs, geometry=list(geom))
#      83 else:
#      84     gdf_edges = gpd.GeoDataFrame(data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\geodataframe.py:139, in GeoDataFrame.__init__(self, data, geometry, crs, *args, **kwargs)
#     133     if (
#     134         kwargs.get("copy") is None
#     135         and isinstance(data, DataFrame)
#     136         and not isinstance(data, GeoDataFrame)
#     137     ):
#     138         kwargs.update(copy=True)
# --> 139     super().__init__(data, *args, **kwargs)
#     141 # set_geometry ensures the geometry data have the proper dtype,
#     142 # but is not called if `geometry=None` ('geometry' column present
#     143 # in the data), so therefore need to ensure it here manually
#    (...)
#     147
#     148 # if gdf passed in and geo_col is set, we use that for geometry
#     149 if geometry is None and isinstance(data, GeoDataFrame):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:814, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     805         columns = ensure_index(columns)
#     806     arrays, columns, index = nested_data_to_arrays(
#     807         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     812         dtype,
#     813     )
# --> 814     mgr = arrays_to_mgr(
#     815         arrays,
#     816         columns,
#     817         index,
#     818         dtype=dtype,
#     819         typ=manager,
#     820     )
#     821 else:
#     822     mgr = ndarray_to_mgr(
#     823         data,
#     824         index,
#    (...)
#     828         typ=manager,
#     829     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:2091, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2089     raise_construction_error(len(arrays), arrays[0].shape, axes, e)
#    2090 if consolidate:
# -> 2091     mgr._consolidate_inplace()
#    2092 return mgr
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1750, in BlockManager._consolidate_inplace(self)
#    1744 def _consolidate_inplace(self) -> None:
#    1745     # In general, _consolidate_inplace should only be called via
#    1746     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1747     #  the DataFrame's _item_cache. The exception is for newly-created
#    1748     #  BlockManager objects not yet attached to a DataFrame.
#    1749     if not self.is_consolidated():
# -> 1750         self.blocks = _consolidate(self.blocks)
#    1751         self._is_consolidated = True
#    1752         self._known_consolidated = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:2217, in _consolidate(blocks)
#    2215 new_blocks: list[Block] = []
#    2216 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2217     merged_blocks, _ = _merge_blocks(
#    2218         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2219     )
#    2220     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2221 return tuple(new_blocks)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:2252, in _merge_blocks(blocks, dtype, can_consolidate)
#    2249     new_values = new_values[argsort]
#    2250     new_mgr_locs = new_mgr_locs[argsort]
# -> 2252     bp = BlockPlacement(new_mgr_locs)
#    2253     return [new_block_2d(new_values, placement=bp)], True
#    2255 # can't consolidate --> no merge
#
# KeyboardInterrupt:

# %% [markdown]
# ### Nick's Fire Polygon Code

# %%
import shapefile as shapefile
#This reads in the shapefile
sf = shapefile.Reader("blockgroups.shp")

#this tells us what type of "shape" is in our shapefile
s=sf.shapeTypeName
print(s)

#this gives us the coordinates of the boundary box of our shape file
sh=sf.bbox
print(sh)

# creating the list of lat/long
test_list = sh

# Making the lat/long points
long = [test_list[i] for i in range(len(sh)) if i % 2 != 0]
lat = [test_list[i] for i in range(len(sh)) if i % 2 == 0]

# printing result
print("The alternate element list is : " + str(long))
print("The alternate element list is : " + str(lat))
